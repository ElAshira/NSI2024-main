# %% [markdown]
# #TD6.1.ArbresBinairesDeRecherche-ParcoursDesArbres
#
#
#
#
#
#
# <p align =center>
#
#  <img src='https://github.com/esabahi/NSI_Images/blob/main/NSI-Image.png?raw=true' width=400>
#
# </p>

# %% [markdown]
# > **<u>Objectifs</u>**
#
# -   Travailler les capacités abordées dans le cours et attendues par le
#     programme officiel sur la définition d’une structure de données en
#     Arbre et les algorithmes de parcours et de recherche.
#
#
# > **<u>Consignes:</u>**
#
# -   Vous pouvez exploiter le code Python de la classe Arbre vu
#     pendantle  cours C2.2.LesArbres ou le TP2.2
#
# -   N'oubliez pas de commenter votre code et de laisser les différents
#     tests que vous auriez effectués sur votre code.

# %% [markdown]
# **Exercice 1 : Arbres Binaires De Recherche**
#
#  **<u>Définition:</u>**
#
# Un arbre binaire de recherche ABR (**Binary Search Tree (BST) en
# anglais)** est un arbre binaire étiqueté avec des clés tel que:
#
# -   Les clés du sous arbre gauche sont inférieures ou égales à celle de
#   la racine;
#
# -   Les clés du sous arbre droit sont strictement supérieures à celle de
#   la racine;
#
# -   Les deux sous arbres sont eux-mêmes des arbres binaires de
#     recherche.
#
# 1.  **<u>Exploiter un arbre binaire de recherche</u>**
#
#     a.  Écrire une fonction **isaBST** qui indique si un arbre binaire
#  est un arbre binaire de recherche

# %%
#Ecrire votre code ci-dessous:
class ArbreBinaire:
      
  def __init__(self, valeur):
    self.contenu = valeur
    self.filsGauche = None
    self.filsDroit = None

  def ajoutFilsGauche(self, valeur):
    if self.filsGauche == None :
      self.filsGauche = ArbreBinaire(valeur)
    else :
      self.filsGauche.ajoutFilsGauche(valeur)

  def ajoutFilsDroit(self, valeur):
    if self.filsDroit == None :
      self.filsDroit = ArbreBinaire(valeur)
    else :
      self.filsDroit.ajoutFilsDroit(valeur)

  def ajoutContenu(self, valeur):
    if valeur != self.contenu:
      if valeur < self.contenu:
        if self.filsGauche == None:      # On peut utiliser la méthode ajoutFilsGauche
          self.filsGauche = ArbreBinaire(valeur)
        else:
          self.filsGauche.ajoutContenu(valeur)
      else:
        if self.filsDroit == None:      # On peut utiliser la méthode ajoutFilsDroit
          self.filsDroit = ArbreBinaire(valeur)
        else:
          self.filsDroit.ajoutContenu(valeur)
  def parcoursProfondeurPrefixe(self):
    print (self.contenu, end=" ")   # On affiche le contenu de la racine de l'arbre passé en paramètre
    if self.filsGauche is not None: # Y a-t'il un fils Gauche
      self.filsGauche.parcoursProfondeurPrefixe()                                            # Oui donc on se relance dessus (recursion sur le sous-arbre gauche)
    if self.filsDroit is not None:                                            # Y a-t'il un fils Droit
      self.filsDroit.parcoursProfondeurPrefixe()                                      # Oui donc on se relance dessus (recursion sur le sous-arbre droit)
  def parcoursProfondeurSuffix(self):
    if self.filsGauche is not None: 
            self.filsGauche.parcoursProfondeurPrefixe()                                            
    if self.filsDroit is not None:                                          
            self.filsDroit.parcoursProfondeurPrefixe()     
    print(self.contenu, end=" ")    

  def __str__(self):
    return ("[ Contenu : {} / Fils Gauche : {} / Fils Droit : {} ] ".format(self.contenu, self.filsGauche, self.filsDroit));
  def parcoursProfondeurInfixe(self):
    if self.filsGauche is not None: 
      self.filsGauche.parcoursProfondeurInfixe()
    print(self.contenu, end=" ")                                      
    if self.filsDroit is not None:                           
      self.filsDroit.parcoursProfondeurInfixe()
  def isaBST(self):
      if (self.filsDroit is not None) and (self.filsGauche is not None):
        if self.filsDroit.contenu >= self.contenu:
          if self.filsGauche.contenu <= self.contenu:
              if self.filsDroit.isaBST() and self.filsGauche.isaBST():
                    return True
          else:
              return False
        else:
              return False
      else:
            return True
arbreWiki = ArbreBinaire(8)           # Instanciation de la racine de l'arbre avec la valeur 8
arbreWiki.ajoutFilsDroit(50)
arbreWiki.ajoutFilsDroit(70)
arbreWiki.ajoutFilsGauche(1)
arbreWiki.ajoutFilsGauche(0)
print(arbreWiki)

arbreWiki.isaBST()
# Out:
# [ Contenu : 8 / Fils Gauche : [ Contenu : 1 / Fils Gauche : [ Contenu : 0 / Fils Gauche : None / Fils Droit : None ]  / Fils Droit : None ]  / Fils Droit : [ Contenu : 50 / Fils Gauche : None / Fils Droit : [ Contenu : 70 / Fils Gauche : None / Fils Droit : None ]  ]  ]
# True

# %% [markdown]
# 2. Écrire une fonction **smallestElementBST** qui renvoie le plus petit élément d’un arbre binaire de recherche

# %%
#Ecrire votre code ci-dessous:
class ArbreBinaire:
      
  def __init__(self, valeur):
    self.contenu = valeur
    self.filsGauche = None
    self.filsDroit = None

  def ajoutFilsGauche(self, valeur):
    if self.filsGauche == None :
      self.filsGauche = ArbreBinaire(valeur)
    else :
      self.filsGauche.ajoutFilsGauche(valeur)

  def ajoutFilsDroit(self, valeur):
    if self.filsDroit == None :
      self.filsDroit = ArbreBinaire(valeur)
    else :
      self.filsDroit.ajoutFilsDroit(valeur)

  def ajoutContenu(self, valeur):
    if valeur != self.contenu:
      if valeur < self.contenu:
        if self.filsGauche == None:      # On peut utiliser la méthode ajoutFilsGauche
          self.filsGauche = ArbreBinaire(valeur)
        else:
          self.filsGauche.ajoutContenu(valeur)
      else:
        if self.filsDroit == None:      # On peut utiliser la méthode ajoutFilsDroit
          self.filsDroit = ArbreBinaire(valeur)
        else:
          self.filsDroit.ajoutContenu(valeur)
  def parcoursProfondeurPrefixe(self):
    print (self.contenu, end=" ")   # On affiche le contenu de la racine de l'arbre passé en paramètre
    if self.filsGauche is not None: # Y a-t'il un fils Gauche
      self.filsGauche.parcoursProfondeurPrefixe()                                            # Oui donc on se relance dessus (recursion sur le sous-arbre gauche)
    if self.filsDroit is not None:                                            # Y a-t'il un fils Droit
      self.filsDroit.parcoursProfondeurPrefixe()                                      # Oui donc on se relance dessus (recursion sur le sous-arbre droit)
  def parcoursProfondeurSuffix(self):
    if self.filsGauche is not None: 
            self.filsGauche.parcoursProfondeurPrefixe()                                            
    if self.filsDroit is not None:                                          
            self.filsDroit.parcoursProfondeurPrefixe()     
    print(self.contenu, end=" ")    

  def __str__(self):
    return ("[ Contenu : {} / Fils Gauche : {} / Fils Droit : {} ] ".format(self.contenu, self.filsGauche, self.filsDroit));
  def parcoursProfondeurInfixe(self):
    if self.filsGauche is not None: 
      self.filsGauche.parcoursProfondeurInfixe()
    print(self.contenu, end=" ")                                      
    if self.filsDroit is not None:                           
      self.filsDroit.parcoursProfondeurInfixe()
  def isaBST(self):
      if (self.filsDroit is not None) and (self.filsGauche is not None):
        if self.filsDroit.contenu >= self.contenu:
          if self.filsGauche.contenu <= self.contenu:
              if self.filsDroit.isaBST() and self.filsGauche.isaBST():
                    return True
          else:
              return False
        else:
              return False
      else:
            return True

  def smallestElementBST(self, smallest):
        if self.filsGauche is None and self.filsDroit is None:
            return min(smallest, self.contenu)
        
        left_smallest = float("inf")  # Ici float("inf") est une representation de l'infini afin de pouvoir couvrir tout les cas du plus petit
        right_smallest = float('inf') # Ici float("inf") est une representation de l'infini afin de pouvoir couvrir tout les cas du plus petit
        
        if self.filsGauche is not None:
            left_biggest = self.filsGauche.smallestElementBST(smallest)
        
        if self.filsDroit is not None:
            right_smallest = self.filsDroit.smallestElementBST(smallest)
        
        return min(left_smallest, right_smallest, self.contenu)
arbreWiki = ArbreBinaire(8)           # Instanciation de la racine de l'arbre avec la valeur 8
arbreWiki.ajoutFilsDroit(50)
arbreWiki.ajoutFilsDroit(70)
arbreWiki.ajoutFilsGauche(5)
arbreWiki.ajoutFilsGauche(4)

print(arbreWiki.smallestElementBST(arbreWiki.contenu))
# Out:
# 4

# %% [markdown]
# 3.  Écrire une fonction **greatestElementBST** qui renvoie le plus grand élément d’un arbre binaire de recherche.

# %%
#Ecrire votre code ci-dessous:
#Ecrire votre code ci-dessous:
class ArbreBinaire:
      
  def __init__(self, valeur):
    self.contenu = valeur
    self.filsGauche = None
    self.filsDroit = None

  def ajoutFilsGauche(self, valeur):
    if self.filsGauche == None :
      self.filsGauche = ArbreBinaire(valeur)
    else :
      self.filsGauche.ajoutFilsGauche(valeur)

  def ajoutFilsDroit(self, valeur):
    if self.filsDroit == None :
      self.filsDroit = ArbreBinaire(valeur)
    else :
      self.filsDroit.ajoutFilsDroit(valeur)

  def ajoutContenu(self, valeur):
    if valeur != self.contenu:
      if valeur < self.contenu:
        if self.filsGauche == None:      # On peut utiliser la méthode ajoutFilsGauche
          self.filsGauche = ArbreBinaire(valeur)
        else:
          self.filsGauche.ajoutContenu(valeur)
      else:
        if self.filsDroit == None:      # On peut utiliser la méthode ajoutFilsDroit
          self.filsDroit = ArbreBinaire(valeur)
        else:
          self.filsDroit.ajoutContenu(valeur)
  def parcoursProfondeurPrefixe(self):
    print (self.contenu, end=" ")   # On affiche le contenu de la racine de l'arbre passé en paramètre
    if self.filsGauche is not None: # Y a-t'il un fils Gauche
      self.filsGauche.parcoursProfondeurPrefixe()                                            # Oui donc on se relance dessus (recursion sur le sous-arbre gauche)
    if self.filsDroit is not None:                                            
      self.filsDroit.parcoursProfondeurPrefixe()                                      
  def parcoursProfondeurSuffix(self):
    if self.filsGauche is not None: 
            self.filsGauche.parcoursProfondeurPrefixe()                                            
    if self.filsDroit is not None:                                          
            self.filsDroit.parcoursProfondeurPrefixe()     
    print(self.contenu, end=" ")    

  def __str__(self):
    return ("[ Contenu : {} / Fils Gauche : {} / Fils Droit : {} ] ".format(self.contenu, self.filsGauche, self.filsDroit));
  def parcoursProfondeurInfixe(self):
    if self.filsGauche is not None: 
      self.filsGauche.parcoursProfondeurInfixe()
    print(self.contenu, end=" ")                                      
    if self.filsDroit is not None:                           
      self.filsDroit.parcoursProfondeurInfixe()
  def isaBST(self):
      if (self.filsDroit is not None) and (self.filsGauche is not None):
        if self.filsDroit.contenu >= self.contenu:
          if self.filsGauche.contenu <= self.contenu:
              if self.filsDroit.isaBST() and self.filsGauche.isaBST():
                    return True
          else:
              return False
        else:
              return False
      else:
            return True

  def smallestElementBST(self, smallest):
        if self.filsGauche is None and self.filsDroit is None:
            return min(smallest, self.contenu)
        
        left_smallest = float("inf")  # Ici float("inf") est une representation de l'infini afin de pouvoir couvrir tout les cas du plus petit
        right_smallest = float('inf') # Ici float("inf") est une representation de l'infini afin de pouvoir couvrir tout les cas du plus petit
        
        if self.filsGauche is not None:
            left_smallest = self.filsGauche.smallestElementBST(smallest)
        
        if self.filsDroit is not None:
            right_smallest = self.filsDroit.smallestElementBST(smallest)
        
        return min(left_smallest, right_smallest, self.contenu)
  def greatestElementBST(self, biggest):
        if self.filsGauche is None and self.filsDroit is None:
            return max(biggest, self.contenu)
        
        left_biggest = float("-inf")  # Ici float("-inf") est une representation de -infini afin de pouvoir couvrir tout les cas du plus grand
        right_biggest = float('-inf') # Ici float("-inf") est une representation de -infini afin de pouvoir couvrir tout les cas du plus grand
        
        if self.filsGauche is not None:
            left_biggest = self.filsGauche.greatestElementBST(biggest)
        
        if self.filsDroit is not None:
            right_biggest = self.filsDroit.greatestElementBST(biggest)
        
        return max(left_biggest, right_biggest, self.contenu)
      
arbreWiki = ArbreBinaire(8)
arbreWiki.ajoutFilsDroit(50)
arbreWiki.ajoutFilsDroit(70)
arbreWiki.ajoutFilsGauche(5)
arbreWiki.ajoutFilsGauche(4)

print(arbreWiki.greatestElementBST(arbreWiki.contenu))
# Out:
# 70

# %% [markdown]
# 4. Écrire un fonction **existElementBST** qui indique si une valeur donnée en paramètre est présente dans un arbre binaire de recherche.

# %%
#Ecrire votre code ci-dessous:
#Ecrire votre code ci-dessous:
#Ecrire votre code ci-dessous:
class ArbreBinaire:
      
  def __init__(self, valeur):
    self.contenu = valeur
    self.filsGauche = None
    self.filsDroit = None

  def ajoutFilsGauche(self, valeur):
    if self.filsGauche == None :
      self.filsGauche = ArbreBinaire(valeur)
    else :
      self.filsGauche.ajoutFilsGauche(valeur)

  def ajoutFilsDroit(self, valeur):
    if self.filsDroit == None :
      self.filsDroit = ArbreBinaire(valeur)
    else :
      self.filsDroit.ajoutFilsDroit(valeur)

  def ajoutContenu(self, valeur):
    if valeur != self.contenu:
      if valeur < self.contenu:
        if self.filsGauche == None:      # On peut utiliser la méthode ajoutFilsGauche
          self.filsGauche = ArbreBinaire(valeur)
        else:
          self.filsGauche.ajoutContenu(valeur)
      else:
        if self.filsDroit == None:      # On peut utiliser la méthode ajoutFilsDroit
          self.filsDroit = ArbreBinaire(valeur)
        else:
          self.filsDroit.ajoutContenu(valeur)
  def parcoursProfondeurPrefixe(self):
    print (self.contenu, end=" ")   # On affiche le contenu de la racine de l'arbre passé en paramètre
    if self.filsGauche is not None: # Y a-t'il un fils Gauche
      self.filsGauche.parcoursProfondeurPrefixe()                                            # Oui donc on se relance dessus (recursion sur le sous-arbre gauche)
    if self.filsDroit is not None:                                            
      self.filsDroit.parcoursProfondeurPrefixe()                                      
  def parcoursProfondeurSuffix(self):
    if self.filsGauche is not None: 
            self.filsGauche.parcoursProfondeurPrefixe()                                            
    if self.filsDroit is not None:                                          
            self.filsDroit.parcoursProfondeurPrefixe()     
    print(self.contenu, end=" ")    

  def __str__(self):
    return ("[ Contenu : {} / Fils Gauche : {} / Fils Droit : {} ] ".format(self.contenu, self.filsGauche, self.filsDroit));
  def parcoursProfondeurInfixe(self):
    if self.filsGauche is not None: 
      self.filsGauche.parcoursProfondeurInfixe()
    print(self.contenu, end=" ")                                      
    if self.filsDroit is not None:                           
      self.filsDroit.parcoursProfondeurInfixe()
  def isaBST(self):
      if (self.filsDroit is not None) and (self.filsGauche is not None):
        if self.filsDroit.contenu >= self.contenu:
          if self.filsGauche.contenu <= self.contenu:
              if self.filsDroit.isaBST() and self.filsGauche.isaBST():
                    return True
          else:
              return False
        else:
              return False
      else:
            return True

  def smallestElementBST(self, smallest):
        if self.filsGauche is None and self.filsDroit is None:
            return min(smallest, self.contenu)
        
        left_smallest = float("inf")  # Ici float("inf") est une representation de l'infini afin de pouvoir couvrir tout les cas du plus petit
        right_smallest = float('inf') # Ici float("inf") est une representation de l'infini afin de pouvoir couvrir tout les cas du plus petit
        
        if self.filsGauche is not None:
            left_smallest = self.filsGauche.smallestElementBST(smallest)
        
        if self.filsDroit is not None:
            right_smallest = self.filsDroit.smallestElementBST(smallest)
        
        return min(left_smallest, right_smallest, self.contenu)
  def greatestElementBST(self, biggest):
        if self.filsGauche is None and self.filsDroit is None:
            return max(biggest, self.contenu)
        
        left_biggest = float("-inf")  # Ici float("-inf") est une representation de -infini afin de pouvoir couvrir tout les cas du plus grand
        right_biggest = float('-inf') # Ici float("-inf") est une representation de -infini afin de pouvoir couvrir tout les cas du plus grand
        
        if self.filsGauche is not None:
            left_biggest = self.filsGauche.greatestElementBST(biggest)
        
        if self.filsDroit is not None:
            right_biggest = self.filsDroit.greatestElementBST(biggest)
        
        return max(left_biggest, right_biggest, self.contenu)

  def existElementBST(self, tree, element):
        if tree is None:
            return False
        if tree.contenu == element:
            return True
        if tree.contenu < element:
            return self.existElementBST(tree.filsDroit, element)
        return self.existElementBST(tree.filsGauche, element)
                
arbreWiki = ArbreBinaire(8)
arbreWiki.ajoutFilsDroit(50)
arbreWiki.ajoutFilsDroit(70)
arbreWiki.ajoutFilsGauche(5)
arbreWiki.ajoutFilsGauche(4)

print(arbreWiki.existElementBST(arbreWiki,25))
# Out:
# False

# %% [markdown]
# 5.  Écrire une fonction **insertElementBST** qui permet d'insérer un élément dans un arbre binaire de recherche.

# %%
#Ecrire votre code ci-dessous:
class ArbreBinaire:
      
  def __init__(self, valeur):
    self.contenu = valeur
    self.filsGauche = None
    self.filsDroit = None

  def ajoutFilsGauche(self, valeur):
    if self.filsGauche == None :
      self.filsGauche = ArbreBinaire(valeur)
    else :
      self.filsGauche.ajoutFilsGauche(valeur)

  def ajoutFilsDroit(self, valeur):
    if self.filsDroit == None :
      self.filsDroit = ArbreBinaire(valeur)
    else :
      self.filsDroit.ajoutFilsDroit(valeur)

  def ajoutContenu(self, valeur):
    if valeur != self.contenu:
      if valeur < self.contenu:
        if self.filsGauche == None:      # On peut utiliser la méthode ajoutFilsGauche
          self.filsGauche = ArbreBinaire(valeur)
        else:
          self.filsGauche.ajoutContenu(valeur)
      else:
        if self.filsDroit == None:      # On peut utiliser la méthode ajoutFilsDroit
          self.filsDroit = ArbreBinaire(valeur)
        else:
          self.filsDroit.ajoutContenu(valeur)
  def parcoursProfondeurPrefixe(self):
    print (self.contenu, end=" ")   # On affiche le contenu de la racine de l'arbre passé en paramètre
    if self.filsGauche is not None: # Y a-t'il un fils Gauche
      self.filsGauche.parcoursProfondeurPrefixe()                                            # Oui donc on se relance dessus (recursion sur le sous-arbre gauche)
    if self.filsDroit is not None:                                            
      self.filsDroit.parcoursProfondeurPrefixe()                                      
  def parcoursProfondeurSuffix(self):
    if self.filsGauche is not None: 
            self.filsGauche.parcoursProfondeurPrefixe()                                            
    if self.filsDroit is not None:                                          
            self.filsDroit.parcoursProfondeurPrefixe()     
    print(self.contenu, end=" ")    

  def __str__(self):
    return ("[ Contenu : {} / Fils Gauche : {} / Fils Droit : {} ] ".format(self.contenu, self.filsGauche, self.filsDroit));
  def parcoursProfondeurInfixe(self):
    if self.filsGauche is not None: 
      self.filsGauche.parcoursProfondeurInfixe()
    print(self.contenu, end=" ")                                      
    if self.filsDroit is not None:                           
      self.filsDroit.parcoursProfondeurInfixe()
  def isaBST(self):
      if (self.filsDroit is not None) and (self.filsGauche is not None):
        if self.filsDroit.contenu >= self.contenu:
          if self.filsGauche.contenu <= self.contenu:
              if self.filsDroit.isaBST() and self.filsGauche.isaBST():
                    return True
          else:
              return False
        else:
              return False
      else:
            return True

  def smallestElementBST(self, smallest):
        if self.filsGauche is None and self.filsDroit is None:
            return min(smallest, self.contenu)
        
        left_smallest = float("inf")  # Ici float("inf") est une representation de l'infini afin de pouvoir couvrir tout les cas du plus petit
        right_smallest = float('inf') # Ici float("inf") est une representation de l'infini afin de pouvoir couvrir tout les cas du plus petit
        
        if self.filsGauche is not None:
            left_smallest = self.filsGauche.smallestElementBST(smallest)
        
        if self.filsDroit is not None:
            right_smallest = self.filsDroit.smallestElementBST(smallest)
        
        return min(left_smallest, right_smallest, self.contenu)
  def greatestElementBST(self, biggest):
        if self.filsGauche is None and self.filsDroit is None:
            return max(biggest, self.contenu)
        
        left_biggest = float("-inf")  # Ici float("-inf") est une representation de -infini afin de pouvoir couvrir tout les cas du plus grand
        right_biggest = float('-inf') # Ici float("-inf") est une representation de -infini afin de pouvoir couvrir tout les cas du plus grand
        
        if self.filsGauche is not None:
            left_biggest = self.filsGauche.greatestElementBST(biggest)
        
        if self.filsDroit is not None:
            right_biggest = self.filsDroit.greatestElementBST(biggest)
        
        return max(left_biggest, right_biggest, self.contenu)

  def existElementBST(self, tree, element):
        if tree is None:
            return False
        if tree.contenu == element:
            return True
        if tree.contenu < element:
            return self.existElementBST(tree.filsDroit, element)
        return self.existElementBST(tree.filsGauche, element)
  def insertElementBST(self, element):
        if element < self.contenu:
            if self.filsGauche is None:
                self.filsGauche = ArbreBinaire(element)
            else:
                self.filsGauche.insertElementBST(element)
        else:
            if self.filsDroit is None:
                self.filsDroit = ArbreBinaire(element)
            else:
                self.filsDroit.insertElementBST(element)
                
arbreWiki = ArbreBinaire(8)
arbreWiki.ajoutFilsDroit(50)
arbreWiki.ajoutFilsDroit(70)
arbreWiki.ajoutFilsGauche(5)
arbreWiki.ajoutFilsGauche(4)

print(arbreWiki.existElementBST(arbreWiki,25))
# Out:
# True
# [ Contenu : 8 / Fils Gauche : [ Contenu : 5 / Fils Gauche : [ Contenu : 4 / Fils Gauche : None / Fils Droit : None ]  / Fils Droit : None ]  / Fils Droit : [ Contenu : 50 / Fils Gauche : [ Contenu : 25 / Fils Gauche : None / Fils Droit : None ]  / Fils Droit : [ Contenu : 70 / Fils Gauche : None / Fils Droit : None ]  ]  ]

# %% [markdown]
# 6.  Écrire une fonction **removeElementBST** qui permet de supprimer un élément dans un arbre binaire de recherche

# %%
#Ecrire votre code ci-dessous:
#Ecrire votre code ci-dessous:
class ArbreBinaire:
      
  def __init__(self, valeur):
    self.contenu = valeur
    self.filsGauche = None
    self.filsDroit = None

  def ajoutFilsGauche(self, valeur):
    if self.filsGauche == None :
      self.filsGauche = ArbreBinaire(valeur)
    else :
      self.filsGauche.ajoutFilsGauche(valeur)

  def ajoutFilsDroit(self, valeur):
    if self.filsDroit == None :
      self.filsDroit = ArbreBinaire(valeur)
    else :
      self.filsDroit.ajoutFilsDroit(valeur)

  def ajoutContenu(self, valeur):
    if valeur != self.contenu:
      if valeur < self.contenu:
        if self.filsGauche == None:      # On peut utiliser la méthode ajoutFilsGauche
          self.filsGauche = ArbreBinaire(valeur)
        else:
          self.filsGauche.ajoutContenu(valeur)
      else:
        if self.filsDroit == None:      # On peut utiliser la méthode ajoutFilsDroit
          self.filsDroit = ArbreBinaire(valeur)
        else:
          self.filsDroit.ajoutContenu(valeur)
  def parcoursProfondeurPrefixe(self):
    print (self.contenu, end=" ")   # On affiche le contenu de la racine de l'arbre passé en paramètre
    if self.filsGauche is not None: # Y a-t'il un fils Gauche
      self.filsGauche.parcoursProfondeurPrefixe()                                            # Oui donc on se relance dessus (recursion sur le sous-arbre gauche)
    if self.filsDroit is not None:                                            
      self.filsDroit.parcoursProfondeurPrefixe()                                      
  def parcoursProfondeurSuffix(self):
    if self.filsGauche is not None: 
            self.filsGauche.parcoursProfondeurPrefixe()                                            
    if self.filsDroit is not None:                                          
            self.filsDroit.parcoursProfondeurPrefixe()     
    print(self.contenu, end=" ")    

  def __str__(self):
    return ("[ Contenu : {} / Fils Gauche : {} / Fils Droit : {} ] ".format(self.contenu, self.filsGauche, self.filsDroit));
  def parcoursProfondeurInfixe(self):
    if self.filsGauche is not None: 
      self.filsGauche.parcoursProfondeurInfixe()
    print(self.contenu, end=" ")                                      
    if self.filsDroit is not None:                           
      self.filsDroit.parcoursProfondeurInfixe()
  def isaBST(self):
      if (self.filsDroit is not None) and (self.filsGauche is not None):
        if self.filsDroit.contenu >= self.contenu:
          if self.filsGauche.contenu <= self.contenu:
              if self.filsDroit.isaBST() and self.filsGauche.isaBST():
                    return True
          else:
              return False
        else:
              return False
      else:
            return True

  def smallestElementBST(self, smallest):
        if self.filsGauche is None and self.filsDroit is None:
            return min(smallest, self.contenu)
        
        left_smallest = float("inf")  # Ici float("inf") est une representation de l'infini afin de pouvoir couvrir tout les cas du plus petit
        right_smallest = float('inf') # Ici float("inf") est une representation de l'infini afin de pouvoir couvrir tout les cas du plus petit
        
        if self.filsGauche is not None:
            left_smallest = self.filsGauche.smallestElementBST(smallest)
        
        if self.filsDroit is not None:
            right_smallest = self.filsDroit.smallestElementBST(smallest)
        
        return min(left_smallest, right_smallest, self.contenu)
  def greatestElementBST(self, biggest):
        if self.filsGauche is None and self.filsDroit is None:
            return max(biggest, self.contenu)
        
        left_biggest = float("-inf")  # Ici float("-inf") est une representation de -infini afin de pouvoir couvrir tout les cas du plus grand
        right_biggest = float('-inf') # Ici float("-inf") est une representation de -infini afin de pouvoir couvrir tout les cas du plus grand
        
        if self.filsGauche is not None:
            left_biggest = self.filsGauche.greatestElementBST(biggest)
        
        if self.filsDroit is not None:
            right_biggest = self.filsDroit.greatestElementBST(biggest)
        
        return max(left_biggest, right_biggest, self.contenu)

  def existElementBST(self, tree, element):
        if tree is None:
            return False
        if tree.contenu == element:
            return True
        if tree.contenu < element:
            return self.existElementBST(tree.filsDroit, element)
        return self.existElementBST(tree.filsGauche, element)
  def insertElementBST(self, element):
        if element < self.contenu:
            if self.filsGauche is None:
                self.filsGauche = ArbreBinaire(element)
                return True
            else:
                self.filsGauche.insertElementBST(element)
                return True
        else:
            if self.filsDroit is None:
                self.filsDroit = ArbreBinaire(element)
                return True
            else:
                self.filsDroit.insertElementBST(element)
                return True
            return False
  def removeElementBST(self, element):
        if element < self.contenu:
            if self.filsGauche:
                self.filsGauche = self.filsGauche.removeElementBST(element)
        elif element > self.contenu:
            if self.filsDroit:
                self.filsDroit = self.filsDroit.removeElementBST(element)
        else:
            if self.filsGauche is None:
                return self.filsDroit
            elif self.filsDroit is None:
                return self.filsGauche
            # Cas ou le noeud à deux fils
            successor = self.filsDroit
            # Recherche du/des fils dans le sous arbre droit
            while successor.filsGauche:
                successor = successor.filsGauche
            # Remplacement de la valeur du noeud a supprimer par la valeur du fils
            self.contenu = successor.contenu
            # Suppression du fils du sous arbre droit
            self.filsDroit = self.filsDroit.removeElementBST(successor.contenu)

        return self
                
arbreWiki = ArbreBinaire(8)
arbreWiki.ajoutFilsDroit(50)
arbreWiki.ajoutFilsDroit(70)
arbreWiki.ajoutFilsGauche(5)
arbreWiki.ajoutFilsGauche(4)
print(arbreWiki)
print(arbreWiki.removeElementBST(50))
# Out:
# [ Contenu : 8 / Fils Gauche : [ Contenu : 5 / Fils Gauche : [ Contenu : 4 / Fils Gauche : None / Fils Droit : None ]  / Fils Droit : None ]  / Fils Droit : [ Contenu : 50 / Fils Gauche : None / Fils Droit : [ Contenu : 70 / Fils Gauche : None / Fils Droit : None ]  ]  ]
# [ Contenu : 8 / Fils Gauche : [ Contenu : 5 / Fils Gauche : [ Contenu : 4 / Fils Gauche : None / Fils Droit : None ]  / Fils Droit : None ]  / Fils Droit : [ Contenu : 70 / Fils Gauche : None / Fils Droit : None ]  ]

# %% [markdown]
# *Exercice 2 : Arbres représentant des expressions arithmétiques**
#
# Les quatres opérations +,-,$\times$,et $\div$sont des opérateurs binaires.
#
# Une expression ne comptant que ces opérations peut être représentée sous
# forme d’arbre binaire comportant deux sortes de nœuds: les noeuds
# internes sont des opérateurs et les feuilles sont des nombres.
#
# 1.  **<u>Représentation</u>**
#
# Représenter par un dessin (sur Drawings par exemple) l’arbre de l’expression suivante (12x9)+(8-5). Joindre votre dessin à votre rendu.
#
# 2.  **<u>Construction d’une instance</u>**
#
# En reprenant le code de la classe Arbre construire une instance E représentant l'expression précédente

# %%
#Ecrire votre code ci-dessous:

# %% [markdown]
# 3.  **<u>Parcours</u>**
#
# -   Choisir le parcours adéquat (parmi les quatre parcours vu en cours) qui permettra une lecture correcte de l’expression ci-dessus puis son affichage.
#
# -   Écrire la fonction permettant son affichage selon le parcours choisi.

# %%
#Ecrire votre code ci-dessous:

# %% [markdown]
# **Exercice 3 : Arbres syntaxiques**
#
# Python dispose d’une grammaire qui indique la structure des programmes.
#
# Lorsque l'interpréteur Python lit du code source, il construit tout
# d’abord l’arbre syntaxique du code.
#
# 1.  **<u>Représentation</u>**
#
# > Dresser l’arbre du programme suivant sur un dessin(menu insertion Dessin):

# %%
a=3
while(a>0):
  a=a-1
  print(a)

# %% [markdown]
# 2.  **<u>Construction d’une instance</u>**
#
# > En reprenant le code de la classe Arbre construire une instance P représentant l’arbre du programme précédent.
#
# 3.  **<u>Parcours</u>**
#
# -   Choisir le parcours adéquat (parmi les quatre parcours vu en cours) qui permettra une lecture correcte du programme.
#
# -   Écrire la fonction permettant son affichage selon le parcours choisi.

# %%
#Ecrire votre code ci-dessous:

# %% [markdown]
# |<span style='color:Blue'> E.S |  | |   | |     |<span style='color:Blue'> NSI Première & Terminale | |   | ||<span style='color:Blue'> Lycée Ozanam (Lille)
# | --- | --- |--- |--- |--- |--- | --- | --- |--- |--- | --- | --- |
